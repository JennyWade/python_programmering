# %%
from pathlib import Path

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
apples = pd.Series([55,22,33,11,36], index=["ICA", "Willys", "Coop", "Hemköp", "Livs"])
apples
apples["Willys"]
# Out:
# 22

# %%
d1 = {11:1, 12:2, 13:3}
pd.Series(d1)
# Out:
# 11    1
# 12    2
# 13    3
# dtype: int64

# %%
df = pd.DataFrame(data=[["Katt", 6, 0.3], ["Hund", 20, 0.6], ["Fågel", 0.2, 0.1]], index=[1, 2, 3], columns=["Animals", "Weight", "Height"])

# %%
print(df)
type(df)
# Out:
#   Animals  Weight  Height
# 1    Katt     6.0     0.3
# 2    Hund    20.0     0.6
# 3   Fågel     0.2     0.1
# pandas.core.frame.DataFrame

# %%
animal = pd.Series(["Cat", "Dog", "Bird"])
weight = pd.Series([6, 20, 0.2])
df_animals = pd.DataFrame({"Animal": animal, "Weight": weight} index=[0,1,2])
df_animals
# Out:
#   File "C:\Users\jenny\AppData\Local\Temp/ipykernel_3084/1088450040.py", line 3
#     df_animals = pd.DataFrame({"Animal": animal, "Weight": weight} index=[0,1,2])
#                                                                    ^
# SyntaxError: invalid syntax

# %%
pokemon_df = pd.read_csv("files/Pokemon.csv")
iris_df = pd.read_json("files/iris.json")

# %%
iris_df.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemod_df = pokemon_df.set_index("Name")
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon_df.sort_values("HP", ascending=False)
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 381  349     Feebas    Water    NaN    200   20      15       20       10
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df_pk = pokemon_df.fillna(0)
df_pk
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire       0    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...
